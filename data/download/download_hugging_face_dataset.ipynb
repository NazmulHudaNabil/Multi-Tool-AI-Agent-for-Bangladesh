# %% [markdown]
# ### All bangladeshi Hospital csv file download from hugging face using hf_hub_download

# %%
from huggingface_hub import hf_hub_download

path = hf_hub_download(
    repo_id="Mahadih534/all-bangladeshi-hospitals",
    filename="all-bangladesh-hosptals.csv",
    repo_type="dataset",
    local_dir="/Users/mdnazmulhudanabil/Documents/Multi-tool ai agent/data/hugging_face_dataset"
)

print(path)
# Out:
# /Users/mdnazmulhudanabil/Documents/Multi-tool ai agent/dataset_save_db/data/all-bangladesh-hosptals.csv

# %% [markdown]
# ### Bangladeshi-Restarurant-Data csv file downlaod from Huggingface using hf_hub_download

# %%
from huggingface_hub import hf_hub_download

path = hf_hub_download(
    repo_id="Mahadih534/Bangladeshi-Restaurant-Data",
    filename="restaurants.csv",
    repo_type="dataset",
    local_dir="/Users/mdnazmulhudanabil/Documents/Multi-tool ai agent/data/hugging_face_dataset"
)

print(path)
# Out:
# /Users/mdnazmulhudanabil/Documents/Multi-tool ai agent/data/hugging_face_dataset/restaurants.csv
